# %% [markdown]
# **PRECOG RECRUITMENT TASK-1**<br>
# Name: Ishan Kavathekar <br>
# Roll no: 2022121003<br>
# FILE: cases_2012.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

plt.style.use('seaborn')

# %%
df = pd.read_csv("/content/drive/Shareddrives/Precog/Precog/cases_2012.csv")

# %%
df.head()
# Out:
#                 ddl_case_id  year  state_code  dist_code  court_no  \
# 0  01-01-01-201508017692012  2012           1          1         1
# 1  01-01-01-201508017702012  2012           1          1         1
# 2  01-01-01-201608017612012  2012           1          1         1
# 3  01-01-01-201908000012012  2012           1          1         1
# 4  01-01-01-201908000022012  2012           1          1         1
#
#                cino             judge_position female_defendant  \
# 0  MHNB030013192012  chief judicial magistrate           0 male
# 1  MHNB030013202012  chief judicial magistrate           0 male
# 2  MHNB030012922012  chief judicial magistrate           0 male
# 3  MHNB030000162012  chief judicial magistrate           0 male
# 4  MHNB030000122012  chief judicial magistrate           0 male
#
#   female_petitioner  female_adv_def  female_adv_pet  type_name  purpose_name  \
# 0     -9998 unclear           -9998           -9999       5682           NaN
# 1     -9998 unclear           -9998           -9999       5682           NaN
# 2     -9998 unclear           -9998           -9999       5985           NaN
# 3          1 female           -9999               0       1849        5009.0
# 4          1 female           -9999               0       1849        5167.0
#
#    disp_name date_of_filing date_of_decision date_first_list date_last_list  \
# 0         26     2012-11-27       2012-11-23      2012-11-23     5000-01-01
# 1         26     2012-11-27       2012-11-23      2012-11-23     5000-01-01
# 2         26     2012-11-21       2012-11-21      2012-11-21     5000-01-01
# 3         22     2012-01-04       2013-12-11      2012-01-27     2013-11-18
# 4         25     2012-01-04       2012-01-04      2012-01-04     2012-01-04
#
#   date_next_list
# 0            NaN
# 1            NaN
# 2            NaN
# 3     2013-12-11
# 4     2012-01-04

# %%
df.shape
# Out:
# (6400783, 19)

# %%
df.columns
# Out:
# Index(['ddl_case_id', 'year', 'state_code', 'dist_code', 'court_no', 'cino',
#        'judge_position', 'female_defendant', 'female_petitioner',
#        'female_adv_def', 'female_adv_pet', 'type_name', 'purpose_name',
#        'disp_name', 'date_of_filing', 'date_of_decision', 'date_first_list',
#        'date_last_list', 'date_next_list'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6400783 entries, 0 to 6400782
# Data columns (total 19 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ddl_case_id        object
#  1   year               int64
#  2   state_code         int64
#  3   dist_code          int64
#  4   court_no           int64
#  5   cino               object
#  6   judge_position     object
#  7   female_defendant   object
#  8   female_petitioner  object
#  9   female_adv_def     int64
#  10  female_adv_pet     int64
#  11  type_name          int64
#  12  purpose_name       float64
#  13  disp_name          int64
#  14  date_of_filing     object
#  15  date_of_decision   object
#  16  date_first_list    object
#  17  date_last_list     object
#  18  date_next_list     object
# dtypes: float64(1), int64(8), object(10)
# memory usage: 927.8+ MB

# %%
df.describe()
# Out:
#             year    state_code     dist_code      court_no  female_adv_def  \
# count  6400783.0  6.400783e+06  6.400783e+06  6.400783e+06    6.400783e+06
# mean      2012.0  1.073300e+01  1.825990e+01  6.173167e+00   -8.072352e+03
# std          0.0  7.867387e+00  1.436838e+01  6.562036e+00    3.943665e+03
# min       2012.0  1.000000e+00  1.000000e+00  1.000000e+00   -9.999000e+03
# 25%       2012.0  3.000000e+00  7.000000e+00  2.000000e+00   -9.999000e+03
# 50%       2012.0  1.000000e+01  1.500000e+01  3.000000e+00   -9.999000e+03
# 75%       2012.0  1.600000e+01  2.600000e+01  8.000000e+00   -9.999000e+03
# max       2012.0  3.300000e+01  7.600000e+01  7.500000e+01    1.000000e+00
#
#        female_adv_pet     type_name  purpose_name     disp_name
# count    6.400783e+06  6.400783e+06  6.156370e+06  6.400783e+06
# mean    -5.498046e+03  3.182234e+03  3.420345e+03  2.437260e+01
# std      4.974512e+03  1.826388e+03  2.000141e+03  1.287958e+01
# min     -9.999000e+03  1.000000e+00  1.000000e+00  1.000000e+00
# 25%     -9.999000e+03  1.671000e+03  1.604000e+03  1.900000e+01
# 50%     -9.998000e+03  2.812000e+03  3.839000e+03  2.400000e+01
# 75%      0.000000e+00  4.916000e+03  4.935000e+03  3.000000e+01
# max      1.000000e+00  6.817000e+03  7.331000e+03  5.100000e+01

# %%
df.isnull().sum()
# Out:
# ddl_case_id               0
# year                      0
# state_code                0
# dist_code                 0
# court_no                  0
# cino                      0
# judge_position            0
# female_defendant          0
# female_petitioner         0
# female_adv_def            0
# female_adv_pet            0
# type_name                 0
# purpose_name         244413
# disp_name                 0
# date_of_filing            0
# date_of_decision     885657
# date_first_list      296226
# date_last_list        45820
# date_next_list       137207
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels = False , cbar = False, cmap = 'viridis')

# %%
df_states = pd.read_csv('/content/drive/Shareddrives/Precog/Precog/Key/cases_state_key.csv')
df_states = df_states[['state_code' , 'state_name']]
df_states = df_states.drop_duplicates().sort_values('state_code')
df_states
# Out:
#      state_code         state_name
# 161           1        Maharashtra
# 0             2     Andhra Pradesh
# 134           3          Karnataka
# 143           4             Kerala
# 99            5   Himachal Pradesh
# 18            6              Assam
# 125           7          Jharkhand
# 27            8              Bihar
# 224           9          Rajasthan
# 242          10         Tamil Nadu
# 206          11             Orissa
# 112          12  Jammu and Kashmir
# 260          13      Uttar Pradesh
# 90           14            Haryana
# 269          15        Uttarakhand
# 278          16        West Bengal
# 81           17            Gujarat
# 45           18       Chhattisgarh
# 188          19            Mizoram
# 251          20            Tripura
# 179          21          Meghalaya
# 215          22             Punjab
# 152          23     Madhya Pradesh
# 233          24             Sikkim
# 170          25            Manipur
# 197          26              Delhi
# 36           27         Chandigarh
# 2            29          Telangana
# 72           30                Goa
# 63           31      Diu and Daman
# 54           32     DNH at Silvasa
# 108          33             Ladakh

# %%
# Merging the tables according to state_code and adding column of state name in 
df = pd.merge(df, df_states,on = 'state_code', how = 'left')

# %%
# We can see state_name added to the dataframe df
df.head()
# Out:
#                 ddl_case_id  year  state_code  dist_code  court_no  \
# 0  01-01-01-201508017692012  2012           1          1         1
# 1  01-01-01-201508017702012  2012           1          1         1
# 2  01-01-01-201608017612012  2012           1          1         1
# 3  01-01-01-201908000012012  2012           1          1         1
# 4  01-01-01-201908000022012  2012           1          1         1
#
#                cino             judge_position female_defendant  \
# 0  MHNB030013192012  chief judicial magistrate           0 male
# 1  MHNB030013202012  chief judicial magistrate           0 male
# 2  MHNB030012922012  chief judicial magistrate           0 male
# 3  MHNB030000162012  chief judicial magistrate           0 male
# 4  MHNB030000122012  chief judicial magistrate           0 male
#
#   female_petitioner  female_adv_def  female_adv_pet  type_name  purpose_name  \
# 0     -9998 unclear           -9998           -9999       5682           NaN
# 1     -9998 unclear           -9998           -9999       5682           NaN
# 2     -9998 unclear           -9998           -9999       5985           NaN
# 3          1 female           -9999               0       1849        5009.0
# 4          1 female           -9999               0       1849        5167.0
#
#    disp_name date_of_filing date_of_decision date_first_list date_last_list  \
# 0         26     2012-11-27       2012-11-23      2012-11-23     5000-01-01
# 1         26     2012-11-27       2012-11-23      2012-11-23     5000-01-01
# 2         26     2012-11-21       2012-11-21      2012-11-21     5000-01-01
# 3         22     2012-01-04       2013-12-11      2012-01-27     2013-11-18
# 4         25     2012-01-04       2012-01-04      2012-01-04     2012-01-04
#
#   date_next_list   state_name
# 0            NaN  Maharashtra
# 1            NaN  Maharashtra
# 2            NaN  Maharashtra
# 3     2013-12-11  Maharashtra
# 4     2012-01-04  Maharashtra

# %%
# state_counts
state_counts = df.state_name.value_counts()[:10].plot(kind ='bar' ,xlabel = "State" , ylabel = "Cases" ,title = "Cases per state (Top 10) : 2012")
plt.show()

# %% [markdown]
# **STANDARDIZING THE DATAFRAME**

# %%
df['female_defendant'] = df['female_defendant'].replace('0 male','male')
df['female_defendant'] = df['female_defendant'].replace('1 female','female')
df['female_defendant'] = df['female_defendant'].replace('-9998 unclear','unclear')
df['female_defendant'] = df['female_defendant'].replace('-9999 missing name','missing')

# %%
df['female_petitioner'].value_counts()
# Out:
# -9998 unclear         2833260
# 0 male                2496341
# 1 female              1056298
# -9999 missing name      14884
# Name: female_petitioner, dtype: int64

# %%
df['female_petitioner'] = df['female_petitioner'].replace('0 male','male')
df['female_petitioner'] = df['female_petitioner'].replace('1 female','female')
df['female_petitioner'] = df['female_petitioner'].replace('-9998 unclear','unclear')
df['female_petitioner'] = df['female_petitioner'].replace('-9999 missing name','missing')
df['female_petitioner'].value_counts()
# Out:
# unclear    2833260
# male       2496341
# female     1056298
# missing      14884
# Name: female_petitioner, dtype: int64

# %%
df['female_adv_def'].value_counts()
# Out:
# -9999    5008770
#  0       1132404
# -9998     158710
#  1        100899
# Name: female_adv_def, dtype: int64

# %%
df['female_adv_def'] = df['female_adv_def'].replace(0,'male')
df['female_adv_def'] = df['female_adv_def'].replace(1,'female')
df['female_adv_def'] = df['female_adv_def'].replace(-9998 ,'unclear')
df['female_adv_def'] = df['female_adv_def'].replace(-9999 ,'missing')
df['female_adv_def'].value_counts()
# Out:
# missing    5008770
# male       1132404
# unclear     158710
# female      100899
# Name: female_adv_def, dtype: int64

# %%
df['female_adv_pet'].value_counts()
# Out:
# -9999    2764539
#  0       2565914
# -9998     755100
#  1        315230
# Name: female_adv_pet, dtype: int64

# %%
df['female_adv_pet'] = df['female_adv_pet'].replace(0,'male')
df['female_adv_pet'] = df['female_adv_pet'].replace(1,'female')
df['female_adv_pet'] = df['female_adv_pet'].replace(-9998 ,'unclear')
df['female_adv_pet'] = df['female_adv_pet'].replace(-9999 ,'missing')
df['female_adv_pet'].value_counts()
# Out:
# missing    2764539
# male       2565914
# unclear     755100
# female      315230
# Name: female_adv_pet, dtype: int64

# %% [markdown]
# **PLOTS**

# %%
plt.title("Defendant Gender - 2012")
plt.bar(df['female_defendant'].value_counts().index.values,df['female_defendant'].value_counts().values)
plt.show()

# %%
plt.title("Petitioner Gender - 2012")
plt.bar(df['female_petitioner'].value_counts().index.values,df['female_petitioner'].value_counts().values)
plt.show()

# %%
plt.title("Defendant Advocate Gender - 2012")
plt.bar(df['female_adv_def'].value_counts().index.values,df['female_adv_def'].value_counts().values)
plt.show()

# %%
plt.title("Petitioner Advocate Gender - 2012")
plt.bar(df['female_adv_pet'].value_counts().index.values,df['female_adv_pet'].value_counts().values)
plt.show()

# %% [markdown]
# **JUDGE DESIGNATION**

# %%
df_pie = pd.DataFrame({'position':df['judge_position'].value_counts().index,'count':df['judge_position'].value_counts().values})
sum = df_pie.loc[10:, 'count'].sum()
df_pie_final = df_pie[:10]


df_pie_final = df_pie_final.append({'position' : 'others','count' : sum} , ignore_index=True)
df_pie_final
# Out:
#                                  position    count
# 0             district and sessions court  1169586
# 1               chief judicial magistrate   841657
# 2               judicial magistrate court   609350
# 3                             civil court   491472
# 4             civil judge junior division   361951
# 5             civil judge senior division   349913
# 6                          criminal cases   297118
# 7   principal district and sessions court   186333
# 8    additional chief judicial magistrate   174163
# 9                   principal civil judge   166497
# 10                                 others  1752743

# %%
fig = px.pie(df_pie_final, values='count', names='position', title='Judge designation - 2012')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ed6b9036-e78e-42f4-a837-f576b6116598" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed6b9036-e78e-42f4-a837-f576b6116598")) {                    Plotly.newPlot(                        "ed6b9036-e78e-42f4-a837-f576b6116598",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"position=%{label}<br>count=%{value}<extra></extra>","labels":["district and sessions court","chief judicial magistrate","judicial magistrate court","civil court","civil judge junior division","civil judge senior division","criminal cases","principal district and sessions court","additional chief judicial magistrate","principal civil judge","others"],"legendgroup":"","name":"","showlegend":true,"values":[1169586,841657,609350,491472,361951,349913,297118,186333,174163,166497,1752743],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorb ...

# %%
# Changing data type of the variables
df['date_of_filing'] = pd.to_datetime(df['date_of_filing'], errors='coerce')
df['date_of_decision'] = pd.to_datetime(df['date_of_decision'], errors='coerce')

# %%
df['date_of_decision'].isnull().sum()
# Out:
# 885906

# %%
df['time_for_decision'] = (df['date_of_decision'] - df['date_of_filing']).dt.days
df.tail()
# Out:
#                       ddl_case_id  year  state_code  dist_code  court_no  \
# 6400778  33-02-02-219800000042012  2012          33          2         2
# 6400779  33-02-02-219800000092012  2012          33          2         2
# 6400780  33-02-02-219800000132012  2012          33          2         2
# 6400781  33-02-02-223800000092012  2012          33          2         2
# 6400782  33-02-03-202100000882012  2012          33          2         3
#
#                      cino             judge_position female_defendant  \
# 6400778  LDLH020000052012   principal district judge             male
# 6400779  LDLH020000022012   principal district judge             male
# 6400780  LDLH020000062012   principal district judge           female
# 6400781  LDLH020000042012   principal district judge             male
# 6400782  LDLH030000012012  chief judicial magistrate             male
#
#         female_petitioner female_adv_def  ... type_name  purpose_name  \
# 6400778              male           male  ...      6139        5167.0
# 6400779              male           male  ...      6139         737.0
# 6400780              male         female  ...      6139        4018.0
# 6400781            female         female  ...      6141        5167.0
# 6400782           unclear           male  ...      1802         737.0
#
#          disp_name  date_of_filing date_of_decision date_first_list  \
# 6400778         24      2012-05-21       2019-05-29      2017-08-08
# 6400779         24      2012-07-07       2019-10-01      2017-08-01
# 6400780         15      2012-09-08       2017-11-01      2017-09-28
# 6400781         24      2012-09-04       2020-06-09      2017-08-04
# 6400782          4      2012-10-12       2018-05-26      2017-08-02
#
#         date_last_list date_next_list state_name time_for_decision
# 6400778     2019-05-29     2019-05-29     Ladakh            2564.0
# 6400779     2019-10-01     2019-10-01     Ladakh            2642.0
# 6400780     2017-11-01     2017-11-01     Ladakh            1880.0
# 6400781     2020-06-09     2020-06-09     Ladakh            2835.0
# 6400782     2018-05-26     2018-05-26     Ladakh            2052.0
#
# [5 rows x 21 columns]

# %%
df['time_for_decision'].fillna(df['time_for_decision'].median(),inplace=True)

# %%
# !pip install geopandas 
# !pip install shapely
# !pip install shapefile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.4 MB/s eta 0:00:00
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 51.7 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas) (21.3)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2022.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas) (3.0.9)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shapely in /usr/local/lib/python3.8/dist-packages (2.0.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.8/dist-packages (from shapely) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement shapefile (from versions: none)
# ERROR: No matching distribution found for shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
fp = '/content/drive/MyDrive/Precog task files/data/IND_adm1.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1 HASC_1  CCN_1 CCA_1  \
# 0   105  IND  India     1  Andaman and Nicobar  IN.AN      0  None
# 1   105  IND  India     2       Andhra Pradesh  IN.AP      0  None
# 2   105  IND  India     3    Arunachal Pradesh  IN.AR      0  None
# 3   105  IND  India     4                Assam  IN.AS      0  None
# 4   105  IND  India     5                Bihar  IN.BR      0  None
#
#            TYPE_1        ENGTYPE_1 NL_NAME_1  \
# 0  Union Territor  Union Territory      None
# 1           State            State      None
# 2           State            State      None
# 3           State            State      None
# 4           State            State      None
#
#                                            VARNAME_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...
# 1                                               None
# 2  Agence de la Frontière du Nord-Est(French-obso...
# 3                                               None
# 4                                               None
#
#                                             geometry
# 0  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...

# %%
# Make column name same
map_df = map_df.rename({'NAME_1': 'state_name'}, axis = 'columns')
map_df.head()
# Out:
#    ID_0  ISO NAME_0  ID_1           state_name HASC_1  CCN_1 CCA_1  \
# 0   105  IND  India     1  Andaman and Nicobar  IN.AN      0  None
# 1   105  IND  India     2       Andhra Pradesh  IN.AP      0  None
# 2   105  IND  India     3    Arunachal Pradesh  IN.AR      0  None
# 3   105  IND  India     4                Assam  IN.AS      0  None
# 4   105  IND  India     5                Bihar  IN.BR      0  None
#
#            TYPE_1        ENGTYPE_1 NL_NAME_1  \
# 0  Union Territor  Union Territory      None
# 1           State            State      None
# 2           State            State      None
# 3           State            State      None
# 4           State            State      None
#
#                                            VARNAME_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...
# 1                                               None
# 2  Agence de la Frontière du Nord-Est(French-obso...
# 3                                               None
# 4                                               None
#
#                                             geometry
# 0  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...

# %% [markdown]
# **CASES PER STATE**

# %%
df['state_name'].value_counts()
# Out:
# Maharashtra          965560
# Uttar Pradesh        961480
# Karnataka            724072
# Gujarat              453985
# Madhya Pradesh       443869
# Kerala               335315
# Rajasthan            330951
# Tamil Nadu           268919
# Punjab               246800
# Haryana              223754
# Bihar                217541
# West Bengal          205429
# Andhra Pradesh       180811
# Telangana            136802
# Orissa               126070
# Delhi                114464
# Assam                 91339
# Chhattisgarh          76565
# Jharkhand             76004
# Uttarakhand           63004
# Himachal Pradesh      62039
# Jammu and Kashmir     28960
# Goa                   26638
# Chandigarh            19580
# Tripura               10902
# Meghalaya              2719
# Manipur                2325
# Mizoram                1866
# Diu and Daman          1332
# Sikkim                  886
# DNH at Silvasa          790
# Ladakh                   12
# Name: state_name, dtype: int64

# %%
df_state_num = pd.DataFrame({'state_name':df['state_name'].value_counts().index.values,'count':df['state_name'].value_counts().values})
df_state_num
# Out:
#            state_name   count
# 0         Maharashtra  965560
# 1       Uttar Pradesh  961480
# 2           Karnataka  724072
# 3             Gujarat  453985
# 4      Madhya Pradesh  443869
# 5              Kerala  335315
# 6           Rajasthan  330951
# 7          Tamil Nadu  268919
# 8              Punjab  246800
# 9             Haryana  223754
# 10              Bihar  217541
# 11        West Bengal  205429
# 12     Andhra Pradesh  180811
# 13          Telangana  136802
# 14             Orissa  126070
# 15              Delhi  114464
# 16              Assam   91339
# 17       Chhattisgarh   76565
# 18          Jharkhand   76004
# 19        Uttarakhand   63004
# 20   Himachal Pradesh   62039
# 21  Jammu and Kashmir   28960
# 22                Goa   26638
# 23         Chandigarh   19580
# 24            Tripura   10902
# 25          Meghalaya    2719
# 26            Manipur    2325
# 27            Mizoram    1866
# 28      Diu and Daman    1332
# 29             Sikkim     886
# 30     DNH at Silvasa     790
# 31             Ladakh      12

# %%
df_merged = pd.merge(map_df,df_state_num,on='state_name', how='left')

df_merged.drop(columns=['ID_0', 'ISO', 'NAME_0', 'ID_1', 'HASC_1', 'CCN_1',
        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1'
      ])
df_merged.columns
# Out:
# Index(['ID_0', 'ISO', 'NAME_0', 'ID_1', 'state_name', 'HASC_1', 'CCN_1',
#        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1', 'geometry',
#        'count'],
#       dtype='object')

# %%
df_merged["count"].fillna(df_merged["count"].median(), inplace = True)
df_merged.head()
# Out:
#    ID_0  ISO NAME_0  ID_1           state_name HASC_1  CCN_1 CCA_1  \
# 0   105  IND  India     1  Andaman and Nicobar  IN.AN      0  None
# 1   105  IND  India     2       Andhra Pradesh  IN.AP      0  None
# 2   105  IND  India     3    Arunachal Pradesh  IN.AR      0  None
# 3   105  IND  India     4                Assam  IN.AS      0  None
# 4   105  IND  India     5                Bihar  IN.BR      0  None
#
#            TYPE_1        ENGTYPE_1 NL_NAME_1  \
# 0  Union Territor  Union Territory      None
# 1           State            State      None
# 2           State            State      None
# 3           State            State      None
# 4           State            State      None
#
#                                            VARNAME_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...
# 1                                               None
# 2  Agence de la Frontière du Nord-Est(French-obso...
# 3                                               None
# 4                                               None
#
#                                             geometry     count
# 0  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...  158806.5
# 1  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...  180811.0
# 2  POLYGON ((96.15778 29.38310, 96.16380 29.37668...  158806.5
# 3  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...   91339.0
# 4  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...  217541.0

# %%
# Judge state
fig, ax = plt.subplots(1, figsize=(10,6))
df_merged.plot(column='count',cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title("Cases per State - 2012")
# Out:
# Text(0.5, 1.0, 'Cases per State - 2012')

# %% [markdown]
# **AVERAGE DURATION OF CASE PER STATE**

# %%
df_days_served = pd.DataFrame({'state_name':df['state_name'],'time_for_decision':df['time_for_decision']})
df_days_mean = df_days_served.groupby('state_name').mean()
df_days_mean.rename(columns={'time_for_decision':'time_for_decision'},inplace=True)

# %%
df_merged_mean_time = pd.merge(map_df,df_days_mean,on='state_name', how='left')
df_merged_mean_time=df_merged_mean_time.drop(columns=['ID_0', 'ISO', 'NAME_0', 'ID_1', 'HASC_1', 'CCN_1',
        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1'])
df_merged_mean_time.head()
# Out:
#             state_name                                           geometry  \
# 0  Andaman and Nicobar  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1       Andhra Pradesh  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2    Arunachal Pradesh  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3                Assam  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4                Bihar  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...
#
#    time_for_decision
# 0                NaN
# 1         815.897230
# 2                NaN
# 3         739.419164
# 4         876.096966

# %%
df_merged_mean_time['time_for_decision'].fillna(df_merged_mean_time['time_for_decision'].median(),inplace=True)

# %%
# Mean time for decision time per state
fig, ax = plt.subplots(1, figsize=(10,6))
df_merged_mean_time.plot(column='time_for_decision',cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title("Mean time for judgement per state - 2012")
# Out:
# Text(0.5, 1.0, 'Mean time for judgement per state - 2012')

# %% [markdown]
# **CASE STATUS**

# %%
df['status'] = df['date_of_decision'].notnull().map({True:'closed',False:'not closed'})

# %%
case_stat = pd.DataFrame({'status':df['status'].value_counts().index.values,'count':df['status'].value_counts().values})

# %%
fig_cases = px.pie(case_stat, values='count', names='status', title='Decision of Cases - 2012')
fig_cases.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="89b9fd41-a76c-463d-8c37-941f168e23a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89b9fd41-a76c-463d-8c37-941f168e23a0")) {                    Plotly.newPlot(                        "89b9fd41-a76c-463d-8c37-941f168e23a0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"status=%{label}<br>count=%{value}<extra></extra>","labels":["closed","not closed"],"legendgroup":"","name":"","showlegend":true,"values":[5515126,885657],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet": ...

# %% [markdown]
# **CASES CLOSED PER STATE**

# %%
df_status_count = df.groupby(['state_name'])['status'].value_counts().to_frame()
df_status_count = df_status_count.rename(columns={'status':'count'})
df_status_count = df_status_count.reset_index(['state_name','status'])
df_status_count.head()
# Out:
#        state_name      status   count
# 0  Andhra Pradesh      closed  172007
# 1  Andhra Pradesh  not closed    8804
# 2           Assam      closed   85583
# 3           Assam  not closed    5756
# 4           Bihar  not closed  117249

# %%
df_closed = pd.DataFrame({'state_name':df_status_count['state_name'],'count':df_status_count.loc[df_status_count['status'] == 'closed']['count']})
df_closed = df_closed.dropna(subset=['count'], how='all')
df_closed.head()
# Out:
#        state_name     count
# 0  Andhra Pradesh  172007.0
# 2           Assam   85583.0
# 5           Bihar  100292.0
# 6      Chandigarh   19370.0
# 8    Chhattisgarh   72730.0

# %%
df_closed_cases = pd.merge(map_df,df_closed,on='state_name', how='left')
df_closed_cases=df_closed_cases.drop(columns=['ID_0', 'ISO', 'NAME_0', 'ID_1', 'HASC_1', 'CCN_1',
        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1'])
df_closed_cases.head()
# Out:
#             state_name                                           geometry  \
# 0  Andaman and Nicobar  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1       Andhra Pradesh  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2    Arunachal Pradesh  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3                Assam  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4                Bihar  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...
#
#       count
# 0       NaN
# 1  172007.0
# 2       NaN
# 3   85583.0
# 4  100292.0

# %%
df_closed_cases['count'].fillna(df_closed_cases['count'].median(),inplace=True)

# %%
# Number of closed cases per state
fig, ax = plt.subplots(1, figsize=(10,6))
df_closed_cases.plot(column='count',cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title("Number of closed cases per state - 2012")
# Out:
# Text(0.5, 1.0, 'Number of closed cases per state - 2012')

# %% [markdown]
# **CASES UNCLOSED PER STATE**

# %%
df_unclosed = pd.DataFrame({'state_name':df_status_count['state_name'],'count':df_status_count.loc[df_status_count['status'] == 'not closed']['count']})
df_unclosed = df_unclosed.dropna(subset=['count'], how='all')
df_unclosed.head()
# Out:
#        state_name     count
# 1  Andhra Pradesh    8804.0
# 3           Assam    5756.0
# 4           Bihar  117249.0
# 7      Chandigarh     210.0
# 9    Chhattisgarh    3835.0

# %%
df_unclosed_cases = pd.merge(map_df,df_unclosed,on='state_name', how='left')
df_unclosed_cases=df_unclosed_cases.drop(columns=['ID_0', 'ISO', 'NAME_0', 'ID_1', 'HASC_1', 'CCN_1',
        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1'])
df_unclosed_cases.head()
# Out:
#             state_name                                           geometry  \
# 0  Andaman and Nicobar  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1       Andhra Pradesh  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2    Arunachal Pradesh  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3                Assam  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4                Bihar  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...
#
#       count
# 0       NaN
# 1    8804.0
# 2       NaN
# 3    5756.0
# 4  117249.0

# %%
df_closed_cases['count'].fillna(df_closed_cases['count'].median(),inplace=True)

# %%
# Number of unclosed cases per state
fig, ax = plt.subplots(1, figsize=(10,6))
df_unclosed_cases.plot(column='count',cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title("Number of unclosed cases per state - 2012")
# Out:
# Text(0.5, 1.0, 'Number of unclosed cases per state - 2012')

# %% [markdown]
# **NUMBER OF CLOSED CASES PER STATE**

# %%
df_courts_num = pd.DataFrame({'state_name':df['state_name'],'court_no':df['court_no']})
df_courts_num = df_courts_num.drop_duplicates()

df_courts_num_final = pd.DataFrame({'state_name':df_courts_num.groupby(['state_name'])['court_no'].sum().index.values,'count':df_courts_num.groupby(['state_name'])['court_no'].sum().values})
df_courts_num_final.head()
# Out:
#        state_name  count
# 0  Andhra Pradesh    906
# 1           Assam    120
# 2           Bihar    155
# 3      Chandigarh      6
# 4    Chhattisgarh    105

# %%
df_courts = pd.merge(map_df,df_courts_num_final,on='state_name', how='left')
df_courts=df_courts.drop(columns=['ID_0', 'ISO', 'NAME_0', 'ID_1', 'HASC_1', 'CCN_1',
        'CCA_1', 'TYPE_1', 'ENGTYPE_1', 'NL_NAME_1', 'VARNAME_1'])
df_courts.head()
# Out:
#             state_name                                           geometry  \
# 0  Andaman and Nicobar  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1       Andhra Pradesh  MULTIPOLYGON (((80.19264 13.52070, 80.19264 13...
# 2    Arunachal Pradesh  POLYGON ((96.15778 29.38310, 96.16380 29.37668...
# 3                Assam  MULTIPOLYGON (((89.87145 25.53730, 89.87118 25...
# 4                Bihar  MULTIPOLYGON (((88.10548 26.53904, 88.10505 26...
#
#    count
# 0    NaN
# 1  906.0
# 2    NaN
# 3  120.0
# 4  155.0

# %%
df_courts['count'].fillna(df_courts['count'].median(),inplace=True)

# %%
# Number of unclosed cases per state
fig, ax = plt.subplots(1, figsize=(10,6))
df_courts.plot(column='count',cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title("Number of courts per state - 2012")
# Out:
# Text(0.5, 1.0, 'Number of courts per state - 2012')

# %% [markdown]
# **CLOSED AND UNCLOSED CASES PER PENDING CASES PER STATE**

# %%
df_unclosed = df_unclosed.rename(columns={'count':'unclosed_count'})
df_closed = df_closed.rename(columns={'count':'closed_count'})
df_courts_cases = pd.merge(df_courts_num_final, df_unclosed,on = 'state_name', how = 'left')
df_courts_cases = pd.merge(df_courts_cases, df_closed,on = 'state_name', how = 'left')
df_courts_cases.head()
# Out:
#        state_name  count  unclosed_count  closed_count
# 0  Andhra Pradesh    906          8804.0      172007.0
# 1           Assam    120          5756.0       85583.0
# 2           Bihar    155        117249.0      100292.0
# 3      Chandigarh      6           210.0       19370.0
# 4    Chhattisgarh    105          3835.0       72730.0

# %%
df_courts_cases['unclosed_avg_count'] = df_courts_cases['unclosed_count'] / df_courts_cases['count']
df_courts_cases['closed_avg_count'] = df_courts_cases['closed_count'] / df_courts_cases['count']
df_courts_cases.head()
# Out:
#        state_name  count  unclosed_count  closed_count  unclosed_avg_count  \
# 0  Andhra Pradesh    906          8804.0      172007.0            9.717439
# 1           Assam    120          5756.0       85583.0           47.966667
# 2           Bihar    155        117249.0      100292.0          756.445161
# 3      Chandigarh      6           210.0       19370.0           35.000000
# 4    Chhattisgarh    105          3835.0       72730.0           36.523810
#
#    closed_avg_count
# 0        189.853201
# 1        713.191667
# 2        647.045161
# 3       3228.333333
# 4        692.666667

# %%
fig_unclosed_avg = px.bar(df_courts_cases, x='state_name', y='unclosed_avg_count', title='Average unclosed cases per court per state - 2012')
fig_unclosed_avg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e850f9ad-a0c1-4e73-a462-63fdad773d24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e850f9ad-a0c1-4e73-a462-63fdad773d24")) {                    Plotly.newPlot(                        "e850f9ad-a0c1-4e73-a462-63fdad773d24",                        [{"alignmentgroup":"True","hovertemplate":"state_name=%{x}<br>unclosed_avg_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","DNH at Silvasa","Delhi","Diu and Daman","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Orissa","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[9.717439293598234,47.96666666666667,756.4451612903226,35.0,36.523809523809526,null,568.9090909090909,null,18.645833333333332,128.74153846153845,20.73076923076923,36.078947368421055,43.90972222222222,335.02777777777777,74.28823529411764,8.359404096834265,null,736.6666666666666,101.6327474560592,2.359375,8.233333333333333,15.1,175.04347826086956,27.99047619047619,30.664610207515423,null,38.24966261808367,19.887356321839082,7.102564102564102,2573.2285714285713,27.99425287356322,223.84584980237153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %%
fig_unclosed_avg = px.bar(df_courts_cases, x='state_name', y='closed_avg_count', title='Average closed cases per court per state - 2012')
fig_unclosed_avg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bcc1d7c4-9bf8-440d-b8cd-6c19a4410ab6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcc1d7c4-9bf8-440d-b8cd-6c19a4410ab6")) {                    Plotly.newPlot(                        "bcc1d7c4-9bf8-440d-b8cd-6c19a4410ab6",                        [{"alignmentgroup":"True","hovertemplate":"state_name=%{x}<br>closed_avg_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","DNH at Silvasa","Delhi","Diu and Daman","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Orissa","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[189.85320088300222,713.1916666666667,647.0451612903225,3228.3333333333335,692.6666666666666,790.0,4634.0,1332.0,536.3125,1268.1353846153845,2847.9102564102564,290.4421052631579,157.20138888888889,1776.1944444444443,1345.4607843137255,147.74627560521415,2.4,11593.027777777777,791.577243293247,33.96875,82.4,171.5,281.731884057971,2322.4857142857145,154.95008412787436,63.285714285714285,324.66396761133603,294.6,132.66666666666666,6583.72380952381,334.0977011494253,588.1264822134387],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...
